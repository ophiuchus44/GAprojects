# %%
import pandas as pd

df = pd.read_csv('/Users/Paul/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-04/assets/indeed-scraped-job-postings.csv')

# %%
df.ix[46,:]
# Out:
# city                                                 San+Francisco
# company                                                  Galvanize
# salary                                              $2,500 a month
# summary          As part of the Residency program, you will rec...
# title            Data Science Resident (DSR), Data Engineering ...
# parsed_salary                                                 2500
# Name: 46, dtype: object

# %%
df.head()
# Out:
#             city                  company                      salary  \
# 0  San+Francisco              MarkMonitor             $180,000 a year
# 1  San+Francisco    Workbridge Associates  $130,000 - $180,000 a year
# 2  San+Francisco                 Mines.io   $80,000 - $120,000 a year
# 3  San+Francisco    Workbridge Associates  $150,000 - $180,000 a year
# 4  San+Francisco  Smith Hanley Associates             $140,000 a year
#
#                                              summary  \
# 0  Data skills (SQL, Hive, Pig). Applying machine...
# 1  3+ years of industry experience in a data scie...
# 2  We are looking for a data scientist/developer ...
# 3  In this position you will share programming an...
# 4  This person will recruit, build and lead a tea...
#
#                        title  parsed_salary
# 0             Data Scientist       180000.0
# 1      Senior Data Scientist       155000.0
# 2  Full-Stack Data Scientist       100000.0
# ...

# %%
test = df.groupby(['title', 'salary'], as_index = False).size()
x = test.sort_values(ascending = False)
x
# Out:
# title                                                            salary
# Research Engineering/ Scientist Associate II - Paleontology...   $3,210 a month                783
# Engineering Scientist Associate - Software Defined Radio Rec...  $5,400 - $6,500 a month       395
# Engineering Scientist - Senior Software Defined Radio Receiv...  $6,250 - $10,833 a month      395
# Director of Data Analytics                                       $170,000 a year               390
# Robotics software engineer (involves machine learning, AI, a...  $70,000 - $100,000 a year     390
# Engineering Scientist Associate - Software Engineering Assoc...  $5,400 - $6,500 a month       389
# Manager Health Information Management Data Analysis HIM          $71,384 - $93,274 a year      389
# Senior Java Computer Scientist                                   $110,000 - $150,000 a year    365
# Senior Data Scientist (Healthcare)                               $120,000 - $155,000 a year    356
# ...

# %%
df[[2]]
# Out:
#                           salary
# 0                $180,000 a year
# 1     $130,000 - $180,000 a year
# 2      $80,000 - $120,000 a year
# 3     $150,000 - $180,000 a year
# 4                $140,000 a year
# 5                $300,000 a year
# 6     $100,000 - $150,000 a year
# 7                $130,000 a year
# 8                $160,000 a year
# 9     $100,000 - $150,000 a year
# 10    $150,000 - $175,000 a year
# 11       $3,811 - $3,889 a month
# 12    $100,000 - $200,000 a year
# 13               $300,000 a year
# 14      $43,692 - $51,120 a year
# 15    $130,000 - $180,000 a year
# 16    $100,000 - $200,000 a year
# 17    $130,000 - $150,000 a year
# 18    $100,000 - $140,000 a year
# 19    $110,000 - $180,000 a year
# 20               $150,000 a year
# 21    $140,000 - $200,000 a year
# 22     $80,000 - $200,000 a year
# 23      $67,500 - $81,600 a year
# 24                $65,000 a year
# 25    $180,000 - $275,000 a year
# 26    $130,000 - $150,000 a year
# ...

# %%
# salary

# %%
yearSalary = df[df['salary'].str.contains("a year")]

yearSalary.shape
# Out:
# (2437, 6)

# %%
# import csv

# yearSalary.to_csv('YearlySalary.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

yearSalary['parsed_salary'].plot.hist(bins = 30)
plt.show()

# %%
tmp = yearSalary.groupby(['title'], as_index = False).size()
x = tmp.sort_values(ascending = False)
x
# Out:
# title
# Director of Data Analytics                                         390
# Robotics software engineer (involves machine learning, AI, a...    390
# Manager Health Information Management Data Analysis HIM            389
# Senior Java Computer Scientist                                     365
# Senior Data Scientist (Healthcare)                                 356
# Director of Predictive Analytics (Statistician)                    334
# Data Scientist                                                      19
# Senior Data Scientist                                                8
# Program Coordinator                                                  4
# Lead Data Scientist                                                  4
# Medical Technologist (Laboratory Information Manager)                2
# Market Research Analyst                                              2
# SR. SCIENTIST                                                        2
# ...

# %%
yearSalary[yearSalary['title'] == 'Director of Data Analytics']['parsed_salary'].plot.hist(bins = 100)
plt.show()

# %%
monthlySalary = df[df['salary'].str.contains("a month")]

# %%
dailySalary = df[df['salary'].str.contains("a day")]

# %%
dailySalary.shape
# Out:
# (2, 6)

# %%
monthlySalary.shape
# Out:
# (2352, 6)

# %%
2352+2437
# Out:
# 4789

# %%
yearSalary.shape
# Out:
# (2437, 6)

# %%
# yearSalary.iloc[46,:]

# %%
monthlySalary
# Out:
#                city                                  company  \
# 11    San+Francisco        University of California Berkeley
# 30    San+Francisco        University of California Berkeley
# 46    San+Francisco                                Galvanize
# 847          Austin            University of Texas at Austin
# 848          Austin            University of Texas at Austin
# 849          Austin            University of Texas at Austin
# 851          Austin            University of Texas at Austin
# 852          Austin            University of Texas at Austin
# 853          Austin        Texas Department of Public Safety
# 854          Austin            University of Texas at Austin
# 855          Austin            University of Texas at Austin
# 856          Austin            Dept of State Health Services
# 858          Austin            University of Texas at Austin
# 860          Austin            University of Texas at Austin
# ...

# %%
monthlySalary['parsed_salary'] = monthlySalary['parsed_salary'] * 12
# Out:
# /Users/Paul/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
monthlySalary
# Out:
#                city                                  company  \
# 11    San+Francisco        University of California Berkeley
# 30    San+Francisco        University of California Berkeley
# 46    San+Francisco                                Galvanize
# 847          Austin            University of Texas at Austin
# 848          Austin            University of Texas at Austin
# 849          Austin            University of Texas at Austin
# 851          Austin            University of Texas at Austin
# 852          Austin            University of Texas at Austin
# 853          Austin        Texas Department of Public Safety
# 854          Austin            University of Texas at Austin
# 855          Austin            University of Texas at Austin
# 856          Austin            Dept of State Health Services
# 858          Austin            University of Texas at Austin
# 860          Austin            University of Texas at Austin
# ...

# %%
allDF = yearSalary.append(monthlySalary)

# %%
allDF
# Out:
#                city                                  company  \
# 0     San+Francisco                              MarkMonitor
# 1     San+Francisco                    Workbridge Associates
# 2     San+Francisco                                 Mines.io
# 3     San+Francisco                    Workbridge Associates
# 4     San+Francisco                  Smith Hanley Associates
# 5     San+Francisco                           HSF Consulting
# 6     San+Francisco                         All-In Analytics
# 7     San+Francisco                                  Brilent
# 8     San+Francisco                           HSF Consulting
# 9     San+Francisco                         All-In Analytics
# 10    San+Francisco                       Jobspring Partners
# 12    San+Francisco                    Workbridge Associates
# 13    San+Francisco                           HSF Consulting
# 14    San+Francisco        University of California Berkeley
# ...

# %% [markdown]
# # Export new list to CSV

# %%
import csv

allDF.to_csv('ALLSalaries.csv')

# %%
# exclude because we're not interested in consulting work right now
dailySalary
# Out:
#          city         company             salary  \
# 438  New+York  Selby Jennings  $650 - $900 a day
# 456  New+York  Selby Jennings  $650 - $900 a day
#
#                                                summary  \
# 438  Senior Quantitative Developer/Machine Learning...
# 456  Senior Quantitative Developer/Machine Learning...
#
#                                                title  parsed_salary
# 438  Senior Quantitative/Machine Learning - Contract            NaN
# 456  Senior Quantitative/Machine Learning - Contract            NaN
