# %%
###############################################################################
##########################    LOAD DATA   #####################################
###############################################################################

import pandas as pd

newData= '/Users/Paul/Desktop/General_Assembly/DSI_SM_01/curriculum/week-02/2.4-lab/assets/datasets/billboard.csv'

df = pd.read_csv(newData)

df.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
###SOME EXPLORATION

df.dtypes


#df.get_dtype_counts()
#df['track'].values
#df['track'].value_counts()
#df.describe

#df.date_entered.values
#df.date_peaked.values

# year                 int64
# artist.inverted     object
# track               object
# time                object
# genre               object
# date.entered        object
# date.peaked         object
# x1st.week            int64
# x2nd.week          float64
# x3rd.week          float64
# Out:
# artist                  object
# track                   object
# time                    object
# genre                   object
# date_entered    datetime64[ns]
# date_peaked     datetime64[ns]
# week_1                 float64
# week_2                 float64
# week_3                 float64
# week_4                 float64
# week_5                 float64
# week_6                 float64
# week_7                 float64
# week_8                 float64
# week_9                 float64
# week_10                float64
# week_11                float64
# week_12                float64
# week_13                float64
# week_14                float64
# week_15                float64
# week_16                float64
# week_17                float64
# week_18                float64
# week_19                float64
# week_20                float64
# week_21                float64
# week_22                float64
# week_23                float64
# week_24                float64
# ...

# %%
##################################################################################
################## clean column names ##########################################
#################################################################################


columns1 = ['year', 'artist', 'track', 'time', 'genre', 'date_entered', 'date_peaked']

weekname = ['week_' + str(i) for i in range(1,77)]
weekname
columns = columns1+weekname

columns

df.columns = columns


##################################################################################
################## clean column names ##########################################
#################################################################################


df.head()
# Out:
#    year               artist                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date_entered date_peaked  week_1  week_2  week_3   ...     week_67  \
# 0  Rock   2000-09-23  2000-11-18      78    63.0    49.0   ...         NaN
# 1  Rock   2000-02-12  2000-04-08      15     8.0     6.0   ...         NaN
# 2  Rock   1999-10-23  2000-01-29      71    48.0    43.0   ...         NaN
# 3  Rock   2000-08-12  2000-09-16      41    23.0    18.0   ...         NaN
# 4  Rock   2000-08-05  2000-10-14      57    47.0    45.0   ...         NaN
#
# ...

# %%
############################################################
##################### run once ##########################
########################################################

del df['year']
df.head()

############################################################
##################### run once ##########################
########################################################
# Out:
#                 artist                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date_entered date_peaked  week_1  week_2  week_3  week_4   ...     week_67  \
# 0   2000-09-23  2000-11-18      78    63.0    49.0    33.0   ...         NaN
# 1   2000-02-12  2000-04-08      15     8.0     6.0     5.0   ...         NaN
# 2   1999-10-23  2000-01-29      71    48.0    43.0    31.0   ...         NaN
# 3   2000-08-12  2000-09-16      41    23.0    18.0    14.0   ...         NaN
# 4   2000-08-05  2000-10-14      57    47.0    45.0    29.0   ...         NaN
#
# ...

# %%
##################################################################################
################## clean week1 from an int to a float #########################
#################################################################################
df['date_entered'] = pd.to_datetime(df['date_entered'])

df['date_peaked'] = pd.to_datetime(df['date_peaked'])

df.head()
##################################################################################
################## turn date into datetime #########################
#################################################################################
# Out:
#                 artist                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date_entered date_peaked  week_1  week_2  week_3  week_4   ...     week_67  \
# 0   2000-09-23  2000-11-18    78.0    63.0    49.0    33.0   ...         NaN
# 1   2000-02-12  2000-04-08    15.0     8.0     6.0     5.0   ...         NaN
# 2   1999-10-23  2000-01-29    71.0    48.0    43.0    31.0   ...         NaN
# 3   2000-08-12  2000-09-16    41.0    23.0    18.0    14.0   ...         NaN
# 4   2000-08-05  2000-10-14    57.0    47.0    45.0    29.0   ...         NaN
#
# ...

# %%
##################################################################################
################## clean week1 from an int to a float #########################
#################################################################################

df['week_1'] = df['week_1'].astype(float)
df.head()


##################################################################################
################## clean week1 from an int to a float #########################
#################################################################################
# Out:
#                 artist                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date_entered date_peaked  week_1  week_2  week_3  week_4   ...     week_67  \
# 0   2000-09-23  2000-11-18    78.0    63.0    49.0    33.0   ...         NaN
# 1   2000-02-12  2000-04-08    15.0     8.0     6.0     5.0   ...         NaN
# 2   1999-10-23  2000-01-29    71.0    48.0    43.0    31.0   ...         NaN
# 3   2000-08-12  2000-09-16    41.0    23.0    18.0    14.0   ...         NaN
# 4   2000-08-05  2000-10-14    57.0    47.0    45.0    29.0   ...         NaN
#
# ...

# %%
##################################################################################
##################       create field time to peak    #########################
#################################################################################


df['time_to_peak'] = df['date_peaked'] - df['date_entered']

df.head()
# Out:
#                 artist                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date_entered date_peaked  week_1  week_2  week_3  week_4      ...       \
# 0   2000-09-23  2000-11-18    78.0    63.0    49.0    33.0      ...
# 1   2000-02-12  2000-04-08    15.0     8.0     6.0     5.0      ...
# 2   1999-10-23  2000-01-29    71.0    48.0    43.0    31.0      ...
# 3   2000-08-12  2000-09-16    41.0    23.0    18.0    14.0      ...
# 4   2000-08-05  2000-10-14    57.0    47.0    45.0    29.0      ...
#
#    week_68  week_69  week_70  week_71  week_72  week_73  week_74  week_75  \
# ...

# %%
##################################################################################
##################       track time to peak    #########################
#################################################################################



trackTime2Peak = df[[3,0,1,82]].sort(['time_to_peak'], ascending = False)



##################################################################################
##################       track time to peak    #########################
#################################################################################

trackTime2Peak.head()
# Out:
# /Users/Paul/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#        genre        artist              track  time_to_peak
# 46      Rock         Creed             Higher      315 days
# 9    Country      Lonestar             Amazed      273 days
# 24      Rock  3 Doors Down         Kryptonite      217 days
# 157     Rock         Amber  Sexual (Li Da Di)      210 days
# 28      Rock           Joe       I Wanna Know      182 days

# %%
#trackTime2Peak['time_to_peak'] = trackTime2Peak['time_to_peak'].astype(int) 

#trackTime2Peak.tail(25)

#trackTime2Peak.dtypes

# %%
######################################################################################################
################## export track time to peak  by track mean week positiion to csv #################
######################################################################################################
import csv

trackTime2Peak.to_csv('TrackTime2Peak.csv')


######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################trackTime2Peak

# %%
###############################################################################################
################################ GENERATES LIST OF DATES ######################################
###############################################################################################

import datetime 

MainDate= []

start = datetime.datetime.strptime('7-1-1999', '%m-%d-%Y')
end = datetime.datetime.strptime('1-1-2001', '%m-%d-%Y')

date_generated = [start + datetime.timedelta(days=x) for x in range (0, (end-start).days)]

for date in date_generated:
    MainDate.append(date.strftime('%m-%d-%Y'))

###############################################################################################
################################ GENERATES LIST OF DATES ######################################
###############################################################################################

# %%
#################################################################################################
################## create pandas dataframe dateDF that will be the index ##########################
#######################################################################################################

dateDF = pd.DataFrame(MainDate, columns = ['date_entered'])
dateDF.head()


#################################################################################################
################## create pandas dataframe dateDF that will be the index ##########################
#######################################################################################################
# Out:
#   date_entered
# 0   07-01-1999
# 1   07-02-1999
# 2   07-03-1999
# 3   07-04-1999
# 4   07-05-1999

# %%
#################################################################################################
###################################### convert to datetime        ######################################
#######################################################################################################

dateDF['date_entered'] = pd.to_datetime(dateDF['date_entered'])

dateDF.head()

#################################################################################################
###################################### convert to datetime        ######################################
#######################################################################################################
# Out:
#   date_entered
# 0   1999-07-01
# 1   1999-07-02
# 2   1999-07-03
# 3   1999-07-04
# 4   1999-07-05

# %%
##################################################
########### genre artist track by weeks ############
###############################################

TrackDF = df.groupby(['genre', 'artist', 'track']).mean()

TrackDF.head()

#################################################
########### genre artist track by weeks ############
###############################################
# Out:
#                                                  week_1  week_2  week_3  \
# genre   artist        track
# Country Adkins, Trace More                         84.0    84.0    75.0
#         Allan, Gary   Smoke Rings In The Dark      80.0    78.0    76.0
#         Black, Clint  Been There                   87.0    73.0    62.0
#         Brock, Chad   A Country Boy Can Survive    93.0    75.0    92.0
#                       Yes!                         90.0    77.0    66.0
#
#                                                  week_4  week_5  week_6  \
# genre   artist        track
# Country Adkins, Trace More                         73.0    73.0    69.0
#         Allan, Gary   Smoke Rings In The Dark      77.0    92.0     NaN
#         Black, Clint  Been There                   58.0    58.0    57.0
#         Brock, Chad   A Country Boy Can Survive     NaN     NaN     NaN
#                       Yes!                         61.0    59.0    47.0
#
# ...

# %%
########################################################################
########### create csv file of genre artist track by weeks ############
##########################################################################

TrackDF.to_csv('GenreArtistTrackbyWeek.csv')

######################################################################
########### create csv file of genre artist track by weeks ############
#######################################################################

# %%
TrackDF2 = pd.pivot_table(df, index = ['genre','artist','track'])

TrackDF2
# Out:
#                                                                     week_1  \
# genre   artist                  track
# Country Adkins, Trace           More                                  84.0
#         Allan, Gary             Smoke Rings In The Dark               80.0
#         Black, Clint            Been There                            87.0
#         Brock, Chad             A Country Boy Can Survive             93.0
#                                 Yes!                                  90.0
#         Brooks & Dunn           You'll Always Be Loved By Me          95.0
#         Brooks, Garth           Do What You Gotta Do                  86.0
#         Byrd, Tracy             Put Your Hand In Mine                 81.0
#         Cagle, Chris            My Love Goes On And On                99.0
#         Chesney, Kenny          I Lost It                             75.0
#                                 What I Need To Do                     79.0
# ...

# %%
TrackDF[[0]].sort(ascending = False)
# Out:
# /Users/Paul/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#                                                                     week_1
# genre   artist                  track
# Rock    matchbox twenty         Bent                                  60.0
#         Zombie Nation           Kernkraft 400                         99.0
#         Williams, Robbie        Angels                                85.0
#         Westlife                Swear It Again                        96.0
#         Wallflowers, The        Sleepwalker                           73.0
#         Vitamin C               The Itch                              86.0
#                                 Graduation (Friends Forever)          81.0
#         Vertical Horizon        You're A God                          64.0
#                                 Everything You Want                   70.0
# ...

# %%
# datedf = pd.date_range('1999-7-1', periods = 200 , freq='D')
# datedf = datedf.index(['date'])

# datedf.head()

# %%
datedf.merge()

# %%
##################################################################################
################## groupby genre by mean week positiion ##########################
#################################################################################

meanDF = df.groupby(['genre']).mean()

meanDF
# Out:
#                 week_1     week_2     week_3     week_4     week_5     week_6  \
# genre
# Country      82.405405  75.256757  71.808219  68.309859  65.271429  62.357143
# Electronica  84.500000  71.000000  64.000000  61.000000  57.000000  54.000000
# Gospel       76.000000  76.000000  74.000000  69.000000  68.000000  67.000000
# Jazz         89.000000  89.000000   7.000000   8.000000  66.000000        NaN
# Latin        73.222222  64.333333  58.777778  52.666667  52.000000  42.625000
# Pop          79.222222  68.000000  65.500000  60.333333  52.125000  40.285714
# R&B          84.086957  74.095238  67.190476  60.894737  61.473684  56.000000
# Rap          85.172414  76.228070  68.781818  63.925926  60.384615  55.714286
# Reggae       72.000000  72.000000  63.000000  56.000000  62.000000  63.000000
# Rock         76.116788  66.852941  60.298507  54.015267  49.330709  45.894309
#
#                 week_7     week_8     week_9    week_10   ...     week_67  \
# ...

# %%
######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################

meanDF.to_csv('GenreMeanGroup.csv')


######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################

# %%
meanTESTDF = df.groupby(['genre']).mean()

meanDF

# %%
##################################################################################
################## pivot table by genre and artist mean week positiion ###########
#################################################################################

import numpy as np

genreArtistPivot = df.pivot_table(index =['genre', 'artist'], aggfunc =[np.mean], margins = True)
genreArtistPivot.head()
# Out:
#                         mean                                                  \
#                       week_1 week_10 week_11 week_12 week_13 week_14 week_15
# genre   artist
# Country Adkins, Trace   84.0    83.0    92.0     NaN     NaN     NaN     NaN
#         Allan, Gary     80.0     NaN     NaN     NaN     NaN     NaN     NaN
#         Black, Clint    87.0    44.0    44.0    55.0    53.0    53.0    63.0
#         Brock, Chad     91.5    31.0    28.0    27.0    22.0    27.0    31.0
#         Brooks & Dunn   95.0    68.0    62.0    56.0    56.0    55.0    62.0
#
#                                                ...                           \
#                       week_16 week_17 week_18  ...   week_7 week_70 week_71
# genre   artist                                 ...
# Country Adkins, Trace     NaN     NaN     NaN  ...     68.0     NaN     NaN
#         Allan, Gary       NaN     NaN     NaN  ...      NaN     NaN     NaN
# ...

# %%
genreArtistGroup = df.groupby(['genre', 'artist']).mean()
genreArtistGroup.head()
# Out:
#                        week_1  week_2  week_3  week_4  week_5  week_6  week_7  \
# genre   artist
# Country Adkins, Trace    84.0    84.0    75.0    73.0    73.0    69.0    68.0
#         Allan, Gary      80.0    78.0    76.0    77.0    92.0     NaN     NaN
#         Black, Clint     87.0    73.0    62.0    58.0    58.0    57.0    51.0
#         Brock, Chad      91.5    76.0    79.0    61.0    59.0    47.0    39.0
#         Brooks & Dunn    95.0    85.0    85.0    85.0    83.0    83.0    82.0
#
#                        week_8  week_9  week_10   ...     week_67  week_68  \
# genre   artist                                   ...
# Country Adkins, Trace    65.0    73.0     83.0   ...         NaN      NaN
#         Allan, Gary       NaN     NaN      NaN   ...         NaN      NaN
#         Black, Clint     47.0    44.0     44.0   ...         NaN      NaN
#         Brock, Chad      33.0    32.0     31.0   ...         NaN      NaN
# ...

# %%
######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################

genreArtistPivot.to_csv('GenreArtistPivot.csv')


######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################

# %%
df[['genre']].head()
# Out:
#   genre
# 0  Rock
# 1  Rock
# 2  Rock
# 3  Rock
# 4  Rock

# %%
##################################################################################
################## groupby artist and genre by mean week positiion ##########################
#################################################################################

meanART = df.groupby(['artist']).mean()
meanART
# Out:
#                          week_1     week_2     week_3      week_4      week_5  \
# artist
# 2 Pac                 87.000000  82.000000  72.000000   77.000000   87.000000
# 2Ge+her               91.000000  87.000000  92.000000         NaN         NaN
# 3 Doors Down          78.500000  73.000000  70.000000   68.000000   66.500000
# 504 Boyz              57.000000  34.000000  25.000000   17.000000   17.000000
# 98�                   51.000000  39.000000  34.000000   26.000000   26.000000
# A*Teens               97.000000  97.000000  96.000000   95.000000  100.000000
# Aaliyah               71.500000  57.500000  44.500000   34.500000   29.500000
# Adams, Yolanda        76.000000  76.000000  74.000000   69.000000   68.000000
# Adkins, Trace         84.000000  84.000000  75.000000   73.000000   73.000000
# Aguilera, Christina   59.333333  45.666667  34.333333   25.000000   19.000000
# Alice Deejay          79.000000  65.000000  53.000000   48.000000   45.000000
# ...

# %%
######################################################################################################
################## export artist mean week positiion to csv #################
######################################################################################################

meanART.to_csv('ArtistGroupWeekMean.csv')


######################################################################################################
################## export pivot table by genre and artist mean week positiion to csv #################
######################################################################################################

# %%
# ##################################################################################
# ################## groupby genre by mean week positiion ##########################
# #################################################################################

# meanDF = df.groupby(['genre']).mean()

# meanDF

# %%
# import csv
# meanDF.to_csv('meanGenre.csv')

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

# meanART.hist(legend = False)
# plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

meanDF.hist()
plt.show()

# %%
meanDF.plot(kind = 'line', stacked = True, legend = False)
plt.show()

# %%
meanDF.plot(kind = 'hist', stacked = True, legend = False)
plt.show()

# %%
plt.meanDF.scatter('genre', y)

# %%
import seaborn as sns

sns.plot(meanDF.index, meanDF['week_1'])

# %%
speedDF = pd.DataFrame[df.genre, df.week_1]

speedDF

# del meanDF['year']
# meanDF

# %%
meanART.plot(legend = False)
plt.show()

# %%
meanART.head()

# %%
df['artist','week_1'].plot()
plt.show()

# %%
df.head()

# %%
date = df.groupby(['track' , 'date_entered', "date_peaked"]).sum()

# %%
date

# %%
df.week_1.dtype

# %%
df.week_2.dtype

# %%
####### Week 1 is an int #####

type(df.columns)

# %%
df.select_dtypes

# %%
#df['week_1'] = df['week_!'].astype(float)

##################################################################################
################## clean week1 from an int to a float #########################
#################################################################################

# %%
df['minute'] = df.time.str.split(':')

# %%
pd.pivot_table(df, index =['genre']).head()
# Out:
#                 week_1    week_10    week_11    week_12    week_13    week_14  \
# genre
# Country      82.405405  52.377049  51.016949  50.714286  52.301887  55.333333
# Electronica  84.500000  55.750000  53.250000  59.750000  49.333333  56.000000
# Gospel       76.000000  59.000000  66.000000  68.000000  61.000000  67.000000
# Jazz         89.000000        NaN        NaN        NaN        NaN        NaN
# Latin        73.222222  43.250000  49.625000  35.285714  39.285714  43.000000
#
#                week_15    week_16    week_17    week_18    ...         week_7  \
# genre                                                      ...
# Country      59.306122  60.977273  65.285714  71.809524    ...      57.692308
# Electronica  60.666667  67.666667  71.333333  73.333333    ...      54.500000
# Gospel       59.000000  63.000000  67.000000  71.000000    ...      61.000000
# Jazz               NaN        NaN        NaN        NaN    ...            NaN
# ...
